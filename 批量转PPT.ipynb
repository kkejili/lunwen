# %%
import os
import pptx
from pptx.util import Inches
import os.path

#ppt_filename = input('输入目标ppt文件名(无需后缀)：')
ppt_filename1 = os.listdir("./")


for i in ppt_filename1[1:]:
    #print(i)
    #os.chdir(i)
    if os.path.isdir(i):
        #print(i)
        os.chdir(i)
        print(i)
        #ppt_filename = os.path.join(path+i)
        full_ppt_filename = '{}.{}'.format(i,'pptx')
        
        #print(full_ppt_filename)
        ppt_file = pptx.Presentation()
        #if os.path.isdir(path+i):


        pic_files = [fn for fn in os.listdir() if fn.endswith('.jpg')]
        #print(pic_files)
        # 按图片编号顺序导入
        for fn in pic_files:
            slide = ppt_file.slides.add_slide(ppt_file.slide_layouts[1])

                    # 为PPTX文件当前幻灯片中第一个文本框设置文字，本文代码中可忽略
            slide.shapes.placeholders[0].text = fn[:fn.rindex('.')]

                    # 导入并为当前幻灯片添加图片，起始位置和尺寸可修改
            slide.shapes.add_picture(fn,Inches(0), Inches(0), Inches(10), Inches(7.5))
            #print('****')
        os.chdir("../")    
        try:
            ppt_file.save(full_ppt_filename)
        except:
            print("wei0")
# Out:
# 10.1—10.7 (2022-8-29 17-45-28)
# 12.12（下） (2022-8-29 17-46-02)
# 12.1—12.12(上) (2022-8-29 17-46-03)
# 13.1—13.13 (2022-8-29 17-46-24)
# 14.1—14.7（上） (2022-8-29 17-46-51)
# 15.1—15.8 (2022-8-29 17-47-04)
# 3.1—3.6 (2022-8-29 17-47-47)
# 4.1—4.5 (2022-8-29 17-47-54)
# 4.8—4.12 (2022-8-29 17-48-02)
# 5.10 (2022-8-29 17-48-11)
# 5.1—5.9 (2022-8-29 17-48-12)
# 6.1—6.5 (2022-8-29 17-48-20)
# 7.1—7.8 (2022-8-29 17-48-34)
# 8.1 (2022-8-29 17-48-51)
# 8.2—8.4 (2022-8-29 17-48-52)
# 8.5—8.8 (2022-8-29 17-48-54)
# 9.10 (2022-8-29 17-49-00)
# 9.1—9.9 (2022-8-29 17-49-00)
# 【CV】全网最详细的深度学习经典模型RESNET解析【京东特邀专家 朱利明】 - 1.全网最详细的深度学习经典模型RESNET解析(Av96693177,P1) (2022-9-2 19-30-05)
# 【精读AI论文】ResNet深度残差网络 - 3.ResNet为什么能解决网络退化问题(Av631694436,P3) (2022-9-2 19-29-39)
# 【精读AI论文】ResNet深度残差网络 - 4.ResNet论文精读：Deep Residual Learning for (Av631694436,P4) (2022-9-2 19-29-41)
# 【精读AI论文】唐宇迪：ResNet深度残差网络论文及网络架构解读（深度学习_计算机视觉_图像处理_ - 1.1-Resnet论文解读(Av591833354,P1) (2022-9-2 19-30-12)
# 【精读AI论文】唐宇迪：ResNet深度残差网络论文及网络架构解读（深度学习_计算机视觉_图像处理_ - 2.2-Resnet网络架构解读(Av591833354,P2) (2022-9-2 19-30-14)
# 【精读AI论文】唐宇迪：ResNet深度残差网络论文及网络架构解读（深度学习_计算机视觉_图像处理_ - 3.3-项目结构概述(Av591833354,P3) (2022-9-2 19-30-14)
# 【精读AI论文】唐宇迪：ResNet深度残差网络论文及网络架构解读（深度学习_计算机视觉_图像处理_ - 4.4-数据集处理方法(Av591833354,P4) (2022-9-2 19-30-15)
# 【精读AI论文】唐宇迪：ResNet深度残差网络论文及网络架构解读（深度学习_计算机视觉_图像处理_ - 5.5-训练数据构建(Av591833354,P5) (2022-9-2 19-30-15)
# 【精读AI论文】唐宇迪：ResNet深度残差网络论文及网络架构解读（深度学习_计算机视觉_图像处理_ - 6.6-网络架构层次解读(Av591833354,P6) (2022-9-2 19-30-16)
# 【精读AI论文】唐宇迪：ResNet深度残差网络论文及网络架构解读（深度学习_计算机视觉_图像处理_ - 7.7-前向传播配置(Av591833354,P7) (2022-9-2 19-30-17)
# 【精读AI论文】唐宇迪：ResNet深度残差网络论文及网络架构解读（深度学习_计算机视觉_图像处理_ - 8.8-训练resnet模型(Av591833354,P8) (2022-9-2 19-30-17)
# 一个简化方法制作自己的分类数据集 - 1.一个简化方法制作自己的分类数据集(Av340328487,P1) (2022-9-2 19-30-18)
# 图像分类-第一课-如何制作自己的数据集 - 1.第一课-如何制作自己的数据集(Av592706215,P1) (2022-9-2 19-30-18)
# 用自己数据集做图像识别Step1.2_制作Dataset。第一大步完结 - 1.用自己数据集做图像识别Step1.2_制作Dataset。第一大步完结(Av807357030,P1) (2022-9-2 19-30-27)
# 第11章 最小生成树11.1—11.10 (2022-8-29 17-45-45)

# %%
import os
import pptx
from pptx.util import Inches


ppt_filename = input('输入目标ppt文件名(无需后缀)：')
full_ppt_filename = '{}.{}'.format(ppt_filename,'pptx')
ppt_file = pptx.Presentation()

pic_files = [fn for fn in os.listdir() if fn.endswith('.jpg')]

# 按图片编号顺序导入
for fn in sorted(pic_files, key=lambda item:int(item[:item.rindex('.')])):
    slide = ppt_file.slides.add_slide(ppt_file.slide_layouts[1])

    # 为PPTX文件当前幻灯片中第一个文本框设置文字，本文代码中可忽略
    slide.shapes.placeholders[0].text = fn[:fn.rindex('.')]

    # 导入并为当前幻灯片添加图片，起始位置和尺寸可修改
    slide.shapes.add_picture(fn, Inches(0), Inches(0), Inches(10), Inches(7.5))
    
ppt_file.save(full_ppt_filename)
# Out:
# 输入目标ppt文件名(无需后缀)：4-9 编写spider完成抓取过程 - 2  (2047) (2022-6-21 22-23-04)

# %%
import os
import pptx
from pptx.util import Inches
import os.path

#ppt_filename = input('输入目标ppt文件名(无需后缀)：')
ppt_filename = os.listdir("./")
path = "./"
for i in ppt_filename:
    full_ppt_filename = '{}.{}'.format(i,'pptx')
    #print(full_ppt_filename)
    ppt_file = pptx.Presentation()
    if os.path.isdir(path+i):
        pic_files = [fn for fn in os.listdir(path+i) if fn.endswith('.jpg')]
        print(pic_files)

# %%
try:
        os.chdir(path+i)
    except:
        print("wuxiaolujing")
    pic_files = [fn for fn in os.listdir() if fn.endswith('.jpg')]
    print(pic_files)
    # 按图片编号顺序导入
    for fn in pic_files:
        slide = ppt_file.slides.add_slide(ppt_file.slide_layouts[1])

                # 为PPTX文件当前幻灯片中第一个文本框设置文字，本文代码中可忽略
        slide.shapes.placeholders[0].text = fn[:fn.rindex('.')]

                # 导入并为当前幻灯片添加图片，起始位置和尺寸可修改
        slide.shapes.add_picture(fn,Inches(0), Inches(0), Inches(10), Inches(7.5))
        #print('****')
    try:
        ppt_file.save(full_ppt_filename)
    except:
        print("wei0")
# Out:
# wuxiaolujing
# []
# wuxiaolujing
# []

# %%
import os
import pptx
from pptx.util import Inches
import os.path

#ppt_filename = input('输入目标ppt文件名(无需后缀)：')
ppt_filename1 = os.listdir("./")
path = "./"

for i in ppt_filename1[1:]:
    if os.path.isdir(i):
        print(i)
# Out:
# 10-1 什么是cookie池？  (1127) (2022-6-21 22-17-20)
# 10-10 实现检测网站cookie是否有效  (0806) (2022-6-21 22-18-06)
# 10-11 如何选择redis的数据结构来保存cookie  (1059) (2022-6-21 22-17-02)
# 10-12 cookie管理器的实现  (2210) (2022-6-21 22-16-01)
# 10-13 启动cookie池服务  (1235) (2022-6-21 22-16-43)
# 10-14 将cookie集成到爬虫项目中  (1534) (2022-6-21 22-16-21)
# 10-15  cookie架构设计改进意见  (0736) (2022-6-21 22-18-34)
# 10-2 cookie池系统设计  (0923) (2022-6-21 22-17-46)
# 10-3 实现cookie池-1  (1012) (2022-6-21 22-17-23)
# 10-4  实现cookie池-2  (1239) (2022-6-21 22-17-02)
# 10-5 改造login方法 - 1  (0958) (2022-6-21 22-17-45)
# 10-6 改造login方法 - 2  (0936) (2022-6-21 22-17-47)
# 10-7 改造login方法-3  (0843) (2022-6-21 22-18-04)
# 10-8 改造login方法-4  (1037) (2022-6-21 22-17-24)
# 10-9 通过抽象基类实现网站轻松接入  (1500) (2022-6-21 22-16-24)
# 11-1  滑动验证码的识别思路  (1517) (2022-6-21 22-15-13)
# 11-2   验证码截屏-1  (1142) (2022-6-21 22-15-49)
# 11-3  验证码截屏-2  (1403) (2022-6-21 22-15-47)
# 11-4 计算出滑动的距离  (1737) (2022-6-21 22-15-12)
# 11-5 计算滑动轨迹  (1800) (2022-6-21 22-15-06)
# 12-1 增量爬虫需要解决的问题  (0936) (2022-6-21 22-18-34)
# 12-1 增量爬虫需要解决的问题  (0936)(1) (2022-6-21 22-19-06)
# 12-2 通过修改scrapy-redis完成增量抓取 -1  (1611) (2022-6-21 22-18-36)
# 12-3 通过修改scrapy-redis完成增量抓取-2  (1413) (2022-6-21 22-18-41)
# 12-4  爬虫数据更新  (0923) (2022-6-21 22-19-06)
# 13-1 elasticsearch介绍  (1821) (2022-6-21 22-31-26)
# 13-10  elasticsearch的简单查询 - 2  (1112) (2022-6-21 22-32-32)
# 13-12  scrapy写入数据到elasticsearch中 - 1  (1416) (2022-6-21 22-31-55)
# 13-13 scrapy写入数据到elasticsearch中 - 2  (1115) (2022-6-21 22-33-01)
# 13-2 elasticsearch安装  (1324) (2022-6-21 22-32-13)
# 13-3 elasticsearch-head插件以及kibana的安装  (2409) (2022-6-21 22-30-57)
# 13-4  elasticsearch的基本概念  (1215) (2022-6-21 22-31-54)
# 13-5  倒排索引  (1124) (2022-6-21 22-32-29)
# 13-6 elasticsearch 基本的索引和文档CRUD操作  (1844) (2022-6-21 22-31-08)
# 13-7 elasticsearch的mget和bulk批量操作  (1236) (2022-6-21 22-32-23)
# 13-8  elasticsearch的mapping映射管理  (2103) (2022-6-21 22-30-52)
# 13-9 elasticsearch的简单查询 - 1  (1456) (2022-6-21 22-31-49)
# 14-1  es完成搜索建议-搜索建议字段保存 - 1  (1345) (2022-6-21 22-21-32)
# 14-2  es完成搜索建议-搜索建议字段保存 - 2  (1334) (2022-6-21 22-21-07)
# 14-3  django实现elasticsearch的搜索建议 - 1  (1957) (2022-6-21 22-20-25)
# 14-4  django实现elasticsearch的搜索建议 - 2  (1815) (2022-6-21 22-20-35)
# 14-5  django实现elasticsearch的搜索功能 -1  (1406) (2022-6-21 22-21-02)
# 14-6  django实现elasticsearch的搜索功能 -2  (1314) (2022-6-21 22-21-39)
# 14-7  django实现搜索结果分页  (0912) (2022-6-21 22-21-40)
# 14-8 搜索记录、热门搜索功能实现 - 1  (1434) (2022-6-21 22-20-37)
# 14-9  搜索记录、热门搜索功能实现 - 2  (1404) (2022-6-21 22-21-03)
# 15-1 scrapyd部署scrapy项目  (2439) (2022-6-21 22-26-40)
# 3-1 技术选型 爬虫能做什么  (0950) (2022-6-21 22-34-12)
# 3-2 正则表达式-1  (1831) (2022-6-21 22-34-07)
# 3-3 正则表达式-2  (1904) (2022-6-21 22-33-50)
# 3-4 正则表达式-3  (2016) (2022-6-21 22-33-43)
# 3-5  深度优先和广度优先原理  (2515) (2022-6-21 22-33-12)
# 3-6 url去重方法  (0744) (2022-6-21 22-34-27)
# 3-7 彻底搞清楚unicode和utf8编码  (1831) (2022-6-21 22-33-27)
# 4-1 重录说明(很重要！！！)  (0447) (2022-6-21 22-26-08)
# 4-10 scrapy中为什么要使用yield  (0949) (2022-6-21 22-25-59)
# 4-11 提取详情页信息  (2316) (2022-6-21 22-22-13)
# 4-12 提取详情页信息  (1813) (2022-6-21 22-24-23)
# 4-13 items的定义和使用 - 1  (1621) (2022-6-21 22-24-55)
# 4-14 items的定义和使用 - 2  (1330) (2022-6-21 22-25-02)
# 4-15 scrapy配置图片下载  (1820) (2022-6-21 22-24-21)
# 4-16 items数据写入到json文件中  (0927) (2022-6-21 22-26-06)
# 4-17 mysql表结构设计  (1321) (2022-6-21 22-25-30)
# 4-18 pipeline数据库保存  (2016) (2022-6-21 22-23-06)
# 4-19 异步方式入库mysql  (1237) (2022-6-21 22-25-42)
# 4-2 scrapy安装和配置  (3030) (2022-6-21 22-21-56)
# 4-20 数据插入主键冲突的解决方法  (0440) (2022-6-21 22-26-31)
# 4-21 itemloader提取信息  (2141) (2022-6-21 22-23-03)
# 4-22 itemloader提取信息  (1906) (2022-6-21 22-23-47)
# 4-23 大规模抓取图片下载出错的问题  (1245) (2022-6-21 22-25-32)
# 4-3 需求分析  (1353) (2022-6-21 22-25-00)
# 4-4 pycharm中调试scrapy源码  (1013) (2022-6-21 22-25-51)
# 4-5 xpath基础语法  (1902) (2022-6-21 22-23-48)
# 4-6 xpath提取元素  (2848) (2022-6-21 22-22-05)
# 4-7 css选择器  (1754) (2022-6-21 22-24-28)
# 4-8 编写spider完成抓取过程 - 1  (1938) (2022-6-21 22-23-48)
# 4-9 编写spider完成抓取过程 - 2  (2047) (2022-6-21 22-23-04)
# 5-1 session和cookie自动登录机制  (2010) (2022-6-21 22-35-54)
# 5-10 requests模拟登陆知乎 - 3（可选观看）  (1221) (2022-6-21 22-37-56)
# 5-11 scrapy模拟知乎登录（可选观看）  (2046) (2022-6-21 22-35-23)
# 5-12 知乎分析以及数据表设计1  (1517) (2022-6-21 22-36-56)
# 5-13 知乎分析以及数据表设计 - 2  (1335) (2022-6-21 22-37-55)
# 5-14 item loder方式提取question - 1  (1457) (2022-6-21 22-37-21)
# 5-15 item loder方式提取question - 2  (1520) (2022-6-21 22-37-13)
# 5-16 item loder方式提取question - 3  (0645) (2022-6-21 22-38-00)
# 5-17 知乎spider爬虫逻辑的实现以及answer的提取 - 1  (1554) (2022-6-21 22-36-52)
# 5-18 知乎spider爬虫逻辑的实现以及answer的提取 - 2  (1704) (2022-6-21 22-36-23)
# 5-19 保存数据到mysql中 -1  (1727) (2022-6-21 22-36-25)
# 5-2 . selenium模拟登录知乎 - 1new  (1700) (2022-6-21 22-35-18)
# 5-20 保存数据到mysql中 -2  (1722) (2022-6-21 22-36-28)
# 5-21 保存数据到mysql中 -3  (1609) (2022-6-21 22-36-51)
# 5-3 . selenium模拟登录知乎-2new  (1533) (2022-6-21 22-36-00)
# 5-4 . selenium模拟登录知乎-3new  (1614) (2022-6-21 22-35-34)
# 5-5 . 知乎倒立文字识别 new  (2425) (2022-6-21 22-34-34)
# 5-6 . selenium自动识别验证码完成模拟登录-1new  (2343) (2022-6-21 22-34-40)
# 5-7 . selenium自动识别验证码完成模拟登录 - 2 new  (1906) (2022-6-21 22-34-52)
# 5-8 requests模拟登陆知乎 - 1(可选观看)  (1332) (2022-6-21 22-37-30)
# 5-9 requests模拟登陆知乎 - 2（可选观看）  (1316) (2022-6-21 22-37-32)
# 6-1  数据表结构设计  (1533) (2022-6-21 22-29-30)
# 6-2 CrawlSpider源码分析-新建CrawlSpider与settings配置  (1250) (2022-6-21 22-30-15)
# 6-3  CrawlSpider源码分析  (2529) (2022-6-21 22-27-21)
# 6-4  Rule和LinkExtractor使用  (1428) (2022-6-21 22-29-01)
# 6-5 拉勾网302之后的模拟登录和cookie传递(网站需要登录时学习本视频教程)  (3211) (2022-6-21 22-26-54)
# 6-6  item loader方式解析职位  (2446) (2022-6-21 22-28-13)
# 6-7  职位数据入库-1  (1901) (2022-6-21 22-28-30)
# 6-8  职位信息入库-2  (1119) (2022-6-21 22-30-16)
# 6-9 网站反爬突破  (1058) (2022-6-21 22-29-31)
# 7-1  爬虫和反爬的对抗过程以及策略  (2017) (2022-6-21 22-41-24)
# 7-10 cookie禁用、自动限速、自定义spider的settings  (0722) (2022-6-21 22-42-54)
# 7-2 scrapy架构源码分析  (1045) (2022-6-21 22-42-23)
# 7-3 Requests和Response介绍  (1018) (2022-6-21 22-42-49)
# 7-4 通过downloadmiddleware随机更换user-agent-1  (1700) (2022-6-21 22-42-19)
# 7-5 通过downloadmiddleware随机更换user-agent - 2  (1713) (2022-6-21 22-42-18)
# 7-6 scrapy实现ip代理池 - 1  (1651) (2022-6-21 22-41-56)
# 7-7 scrapy实现ip代理池 - 2  (1739) (2022-6-21 22-41-54)
# 7-8 scrapy实现ip代理池 - 3  (1846) (2022-6-21 22-41-27)
# 7-9 云打码实现验证码识别  (2237) (2022-6-21 22-41-26)
# 8-1 selenium动态网页请求与模拟登录知乎  (2124) (2022-6-21 22-39-39)
# 8-10  scrapy的数据收集  (1344) (2022-6-21 22-40-12)
# 8-11 scrapy信号详解  (1305) (2022-6-21 22-40-31)
# 8-12 scrapy扩展开发  (1316) (2022-6-21 22-40-28)
# 8-2 selenium模拟登录微博， 模拟鼠标下拉  (1106) (2022-6-21 22-40-32)
# 8-3  chromedriver不加载图片、phantomjs获取动态网页  (0959) (2022-6-21 22-40-59)
# 8-4 selenium集成到scrapy中  (1943) (2022-6-21 22-39-44)
# 8-5 其余动态网页获取技术介绍-chrome无界面运行、scrapy-splash、selenium-grid, splinter  (0750) (2022-6-21 22-40-59)
# 8-6 scrapy的暂停与重启  (1258) (2022-6-21 22-40-04)
# 8-7 scrapy url去重原理  (0545) (2022-6-21 22-41-09)
# 8-8 scrapy telnet服务  (0737) (2022-6-21 22-41-05)
# 8-9  spider middleware 详解  (1525) (2022-6-21 22-40-04)
# 9-1 分布式爬虫要点  (0839) (2022-6-21 22-39-20)
# 9-2  redis基础知识 - 1  (2031) (2022-6-21 22-38-15)
# 9-3 redis基础知识 - 2  (1558) (2022-6-21 22-38-37)
# 9-4  scrapy-redis编写分布式爬虫代码  (2106) (2022-6-21 22-38-10)
# 9-5  scrapy源码解析-connection.py、defaults.py-  (1105) (2022-6-21 22-39-10)
# 9-6 scrapy-redis源码剖析-dupefilter.py-  (0529) (2022-6-21 22-39-34)
# 9-7  scrapy-redis源码剖析- pipelines.py、 queue.py-  (1041) (2022-6-21 22-39-11)
# 9-8  scrapy-redis源码分析- scheduler.py、spider.py-  (1152) (2022-6-21 22-39-04)
# 9-9 集成bloomfilter到scrapy-redis中  (1930) (2022-6-21 22-38-36)
# 韦东山Android中C++4 (2022-8-6 13-53-16)
# 韦东山Android中C++异常智能指针1 (2022-8-6 13-53-51)
# 韦东山Android中C++重载 (2022-8-6 13-54-22)
# 韦东山Android指针1 (2022-8-6 15-20-14)
# 韦东山Android音频1 (2022-8-6 12-58-44)
# 韦东山Android音频2 (2022-8-6 13-05-53)
# 韦东山Android音频前1 (2022-8-6 23-22-53)
# 韦东山Android驱动深度开发视频1 (2022-8-6 14-26-45)
# 韦东山Android驱动深度开发视频2 (2022-8-6 14-45-01)
# 韦东山Android驱动深度开发视频3 (2022-8-6 14-49-30)
# 韦东山Android驱动深度开发视频4 (2022-8-6 14-50-56)
# 韦东山Android驱动深度开发视频5 (2022-8-6 14-51-54)
# 韦东山HDMI1学习 (2022-8-6 13-30-42)
# 韦东山HDMI音视频Android1 (2022-8-6 13-31-27)
# 韦东山HDMI音视频Android2 (2022-8-6 13-35-27)
# 韦东山Java中Android1 (2022-8-6 13-55-24)
# 韦东山Java包异常1 (2022-8-6 13-55-30)
# 韦东山Java完1 (2022-8-6 13-56-07)
# 韦东山Makefile编写1 (2022-8-6 15-22-12)
# 韦东山三期1 (2022-8-6 18-30-39)
# 韦东山三期音频123 (2022-8-6 18-50-40)
# 韦东山二期IIC通信1 (2022-8-6 19-05-31)
# 韦东山二期视频12345 (2022-8-6 23-27-48)
# 韦东山电子书三期1 (2022-8-6 15-26-39)
# 韦东山电子书三期2 (2022-8-6 15-46-06)
# 韦东山第三期ALSA音频 (2022-8-6 15-46-59)
# 韦东山第三期ALSA音频1 (2022-8-6 16-09-11)
# 韦东山设计模式Android1 (2022-8-6 16-10-33)
# 韦东山音视频Android3 (2022-8-6 13-35-34)
